# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
api_key="02eaf853bed2b6830c2448ce60bf7a1b"
base_url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+api_key

# %%
city_name=[]
cloudiness=[]
country=[]
date=[]
humidity=[]
max_temp=[]
lat=[]
lng=[]
wind_speed=[]
city_record=[]
#Print to logger
print("Begin Data Retrival")
print("----------------------------")
counter=1
for city in cities:
    try:
        
        response=requests.get(f"{base_url}&q={city}").json()
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record.append(response["name"])
        print(f"Processing Record {counter}  | {city}")
        counter=counter+1
    except:
        print("City not found, skipping.....")

print("----------------------------")        
print("Data Retrival Complete")
print("----------------------------")
# Out:
# Begin Data Retrival
# ----------------------------
# Processing Record 1  | north bend
# Processing Record 2  | nurota
# Processing Record 3  | jamestown
# Processing Record 4  | port elizabeth
# Processing Record 5  | mackay
# Processing Record 6  | mataura
# City not found, skipping.....
# Processing Record 7  | fagernes
# Processing Record 8  | saldanha
# Processing Record 9  | nikolskoye
# Processing Record 10  | busselton
# Processing Record 11  | dingle
# Processing Record 12  | hobart
# Processing Record 13  | katsuura
# Processing Record 14  | new norfolk
# City not found, skipping.....
# Processing Record 15  | rikitea
# Processing Record 16  | ushuaia
# Processing Record 17  | shubarshi
# Processing Record 18  | punta arenas
# Processing Record 19  | palmer
# Processing Record 20  | baijiantan
# Processing Record 21  | mazyr
# Processing Record 22  | geraldton
# Processing Record 23  | lebu
# Processing Record 24  | san remigio
# Processing Record 25  | burla
# Processing Record 26  | upernavik
# Processing Record 27  | vaini
# Processing Record 28  | adrar
# Processing Record 29  | socorro
# Processing Record 30  | dikson
# Processing Record 31  | matagami
# Processing Record 32  | fairbanks
# Processing Record 33  | hamilton
# Processing Record 34  | albany
# Processing Record 35  | la ronge
# City not found, skipping.....
# City not found, skipping.....
# Processing Record 36  | yumen
# Processing Record 37  | chaman
# Processing Record 38  | kaeo
# Processing Record 39  | severodvinsk
# Processing Record 40  | margate
# Processing Record 41  | grindavik
# City not found, skipping.....
# Processing Record 42  | jacareacanga
# Processing Record 43  | lata
# Processing Record 44  | tasiilaq
# Processing Record 45  | kavieng
# Processing Record 46  | east london
# Processing Record 47  | mahibadhoo
# Processing Record 48  | bluff
# Processing Record 49  | mar del plata
# City not found, skipping.....
# Processing Record 50  | kruisfontein
# Processing Record 51  | prince rupert
# Processing Record 52  | yangjiang
# Processing Record 53  | jiangkou
# Processing Record 54  | caravelas
# Processing Record 55  | abu dhabi
# Processing Record 56  | castro
# Processing Record 57  | norman wells
# Processing Record 58  | nador
# Processing Record 59  | port alfred
# Processing Record 60  | yellowknife
# Processing Record 61  | zhigansk
# Processing Record 62  | marakkanam
# Processing Record 63  | puerto ayora
# Processing Record 64  | murindo
# Processing Record 65  | guerrero negro
# Processing Record 66  | ljungby
# Processing Record 67  | dalbandin
# Processing Record 68  | birao
# Processing Record 69  | vao
# Processing Record 70  | lavrentiya
# Processing Record 71  | biak
# Processing Record 72  | hithadhoo
# City not found, skipping.....
# City not found, skipping.....
# Processing Record 73  | bantva
# Processing Record 74  | muncar
# Processing Record 75  | ribeira grande
# Processing Record 76  | gloversville
# Processing Record 77  | beauceville
# Processing Record 78  | praya
# Processing Record 79  | kapaa
# Processing Record 80  | mount gambier
# City not found, skipping.....
# Processing Record 81  | hermanus
# Processing Record 82  | inirida
# Processing Record 83  | pevek
# Processing Record 84  | khatanga
# Processing Record 85  | bathsheba
# Processing Record 86  | saskylakh
# Processing Record 87  | tuktoyaktuk
# Processing Record 88  | ancud
# Processing Record 89  | kulashi
# Processing Record 90  | puerto baquerizo moreno
# Processing Record 91  | luganville
# Processing Record 92  | tilichiki
# Processing Record 93  | hay river
# Processing Record 94  | saint-pierre
# Processing Record 95  | saint-philippe
# Processing Record 96  | goderich
# Processing Record 97  | pokrovskoye
# Processing Record 98  | kodiak
# Processing Record 99  | constantine
# Processing Record 100  | inhambane
# Processing Record 101  | namatanai
# Processing Record 102  | port keats
# Processing Record 103  | kudahuvadhoo
# Processing Record 104  | durban
# Processing Record 105  | butaritari
# Processing Record 106  | hilo
# Processing Record 107  | amapa
# City not found, skipping.....
# Processing Record 108  | victoria
# Processing Record 109  | lundazi
# Processing Record 110  | husavik
# Processing Record 111  | cabo san lucas
# Processing Record 112  | atuona
# Processing Record 113  | esperance
# Processing Record 114  | pisco
# Processing Record 115  | kichera
# Processing Record 116  | webster
# Processing Record 117  | college
# Processing Record 118  | georgetown
# Processing Record 119  | iqaluit
# Processing Record 120  | qaanaaq
# Processing Record 121  | souillac
# Processing Record 122  | ponta do sol
# Processing Record 123  | doljo
# Processing Record 124  | cape town
# Processing Record 125  | nemuro
# Processing Record 126  | coihaique
# Processing Record 127  | bouna
# City not found, skipping.....
# Processing Record 128  | yining
# Processing Record 129  | karlskrona
# City not found, skipping.....
# Processing Record 130  | chaumont
# Processing Record 131  | mildura
# Processing Record 132  | barrow
# Processing Record 133  | francisco beltrao
# Processing Record 134  | taurage
# Processing Record 135  | bethel
# Processing Record 136  | tazovskiy
# City not found, skipping.....
# Processing Record 137  | avarua
# Processing Record 138  | hovd
# Processing Record 139  | charlestown
# Processing Record 140  | bredasdorp
# Processing Record 141  | thompson
# Processing Record 142  | nipawin
# Processing Record 143  | guymon
# Processing Record 144  | buenaventura
# Processing Record 145  | okhotsk
# Processing Record 146  | nuevo progreso
# Processing Record 147  | bulawayo
# Processing Record 148  | tarko-sale
# Processing Record 149  | kilis
# Processing Record 150  | nanortalik
# Processing Record 151  | airai
# Processing Record 152  | bilma
# Processing Record 153  | gao
# Processing Record 154  | leningradskiy
# Processing Record 155  | faanui
# Processing Record 156  | teknaf
# Processing Record 157  | nishihara
# Processing Record 158  | werda
# City not found, skipping.....
# Processing Record 159  | kosa
# Processing Record 160  | gorontalo
# Processing Record 161  | lorengau
# Processing Record 162  | gillette
# Processing Record 163  | padang
# City not found, skipping.....
# Processing Record 164  | san rafael
# Processing Record 165  | bossangoa
# Processing Record 166  | mahebourg
# Processing Record 167  | kununurra
# Processing Record 168  | plerin
# Processing Record 169  | arraial do cabo
# City not found, skipping.....
# Processing Record 170  | awjilah
# Processing Record 171  | araouane
# City not found, skipping.....
# Processing Record 172  | alyangula
# Processing Record 173  | ambilobe
# Processing Record 174  | torbay
# Processing Record 175  | ust-barguzin
# Processing Record 176  | sfantu gheorghe
# Processing Record 177  | lira
# Processing Record 178  | ilebo
# Processing Record 179  | maku
# Processing Record 180  | dunedin
# Processing Record 181  | cahors
# Processing Record 182  | candolim
# City not found, skipping.....
# Processing Record 183  | terney
# Processing Record 184  | tungor
# Processing Record 185  | cherskiy
# Processing Record 186  | de-kastri
# Processing Record 187  | ammon
# Processing Record 188  | tual
# Processing Record 189  | egvekinot
# Processing Record 190  | aklavik
# City not found, skipping.....
# Processing Record 191  | rio gallegos
# Processing Record 192  | aksarka
# Processing Record 193  | murdochville
# Processing Record 194  | tiksi
# Processing Record 195  | sahuaripa
# City not found, skipping.....
# Processing Record 196  | lazaro cardenas
# Processing Record 197  | luocheng
# Processing Record 198  | jiayuguan
# Processing Record 199  | carnarvon
# Processing Record 200  | commerce
# Processing Record 201  | zharkent
# Processing Record 202  | katherine
# Processing Record 203  | kijini
# Processing Record 204  | gitega
# Processing Record 205  | huntsville
# Processing Record 206  | tahe
# Processing Record 207  | isangel
# City not found, skipping.....
# Processing Record 208  | abu samrah
# Processing Record 209  | ambagarh chauki
# City not found, skipping.....
# City not found, skipping.....
# City not found, skipping.....
# City not found, skipping.....
# Processing Record 210  | bharatpur
# Processing Record 211  | kasongo
# Processing Record 212  | buraydah
# Processing Record 213  | saint anthony
# Processing Record 214  | putina
# Processing Record 215  | aykhal
# Processing Record 216  | espanola
# Processing Record 217  | alofi
# City not found, skipping.....
# Processing Record 218  | erenhot
# City not found, skipping.....
# City not found, skipping.....
# Processing Record 219  | atar
# Processing Record 220  | kindersley
# City not found, skipping.....
# City not found, skipping.....
# Processing Record 221  | ajdabiya
# Processing Record 222  | salalah
# Processing Record 223  | krasnoarmeyskiy
# Processing Record 224  | cabedelo
# Processing Record 225  | clyde river
# Processing Record 226  | lasa
# Processing Record 227  | boa vista
# Processing Record 228  | mbandaka
# City not found, skipping.....
# Processing Record 229  | arrifes
# Processing Record 230  | hualmay
# Processing Record 231  | taksimo
# Processing Record 232  | naze
# Processing Record 233  | moree
# Processing Record 234  | marawi
# Processing Record 235  | bereda
# Processing Record 236  | constitucion
# Processing Record 237  | borogontsy
# Processing Record 238  | comodoro rivadavia
# Processing Record 239  | namasuba
# Processing Record 240  | loiza
# Processing Record 241  | canarana
# Processing Record 242  | aneho
# Processing Record 243  | sawang daen din
# Processing Record 244  | lompoc
# Processing Record 245  | longyearbyen
# Processing Record 246  | hobyo
# Processing Record 247  | bara
# Processing Record 248  | richards bay
# City not found, skipping.....
# Processing Record 249  | rocha
# Processing Record 250  | mapiripan
# Processing Record 251  | san patricio
# Processing Record 252  | kontagora
# Processing Record 253  | genhe
# Processing Record 254  | sosnovo
# Processing Record 255  | balgazyn
# Processing Record 256  | fethiye
# Processing Record 257  | durusu
# City not found, skipping.....
# Processing Record 258  | ternate
# Processing Record 259  | kaitangata
# Processing Record 260  | florence
# Processing Record 261  | murgab
# Processing Record 262  | ostrovnoy
# City not found, skipping.....
# Processing Record 263  | severo-kurilsk
# Processing Record 264  | diego de almagro
# City not found, skipping.....
# Processing Record 265  | el paisnal
# City not found, skipping.....
# City not found, skipping.....
# City not found, skipping.....
# Processing Record 266  | pizhma
# Processing Record 267  | merrill
# Processing Record 268  | mattru
# Processing Record 269  | champerico
# City not found, skipping.....
# Processing Record 270  | masunga
# Processing Record 271  | gravdal
# Processing Record 272  | vila franca do campo
# Processing Record 273  | troy
# Processing Record 274  | zhezkazgan
# Processing Record 275  | bandarbeyla
# Processing Record 276  | lucapa
# Processing Record 277  | chinhoyi
# Processing Record 278  | rio de janeiro
# Processing Record 279  | shache
# Processing Record 280  | flinders
# Processing Record 281  | igrim
# Processing Record 282  | nanakuli
# Processing Record 283  | lisakovsk
# Processing Record 284  | chokurdakh
# Processing Record 285  | progreso
# Processing Record 286  | kokopo
# Processing Record 287  | mandalgovi
# Processing Record 288  | broome
# Processing Record 289  | staryy nadym
# Processing Record 290  | weligama
# Processing Record 291  | acapulco
# Processing Record 292  | daru
# Processing Record 293  | kilindoni
# Processing Record 294  | moranbah
# City not found, skipping.....
# Processing Record 295  | luderitz
# Processing Record 296  | fortuna
# Processing Record 297  | ahipara
# Processing Record 298  | wilmington
# Processing Record 299  | staroutkinsk
# City not found, skipping.....
# Processing Record 300  | ilulissat
# Processing Record 301  | mirnyy
# Processing Record 302  | longyan
# Processing Record 303  | hami
# Processing Record 304  | grand-santi
# Processing Record 305  | itarema
# City not found, skipping.....
# Processing Record 306  | nouakchott
# Processing Record 307  | cape coast
# Processing Record 308  | lethem
# City not found, skipping.....
# Processing Record 309  | pitimbu
# Processing Record 310  | gushikawa
# Processing Record 311  | tala
# Processing Record 312  | lagoa
# Processing Record 313  | davenda
# Processing Record 314  | moyale
# Processing Record 315  | kamenka
# Processing Record 316  | northam
# Processing Record 317  | buta
# Processing Record 318  | amarillo
# Processing Record 319  | martapura
# Processing Record 320  | vila velha
# Processing Record 321  | high level
# Processing Record 322  | cayenne
# Processing Record 323  | panaba
# Processing Record 324  | provideniya
# Processing Record 325  | halifax
# Processing Record 326  | sinnamary
# Processing Record 327  | dobsice
# City not found, skipping.....
# Processing Record 328  | belmonte
# Processing Record 329  | jiblah
# Processing Record 330  | dicabisagan
# Processing Record 331  | petropavl
# Processing Record 332  | muros
# Processing Record 333  | auki
# Processing Record 334  | codrington
# Processing Record 335  | senno
# Processing Record 336  | zarand
# Processing Record 337  | winslow
# Processing Record 338  | tommot
# Processing Record 339  | rincon
# Processing Record 340  | panguna
# Processing Record 341  | zhangjiakou
# Processing Record 342  | walvis bay
# Processing Record 343  | bridgetown
# Processing Record 344  | sibu
# Processing Record 345  | giyani
# Processing Record 346  | hasaki
# Processing Record 347  | ikalamavony
# Processing Record 348  | sao gabriel
# Processing Record 349  | saint leonard
# Processing Record 350  | qiongshan
# Processing Record 351  | concepcion del oro
# Processing Record 352  | sao filipe
# Processing Record 353  | baruun-urt
# City not found, skipping.....
# Processing Record 354  | bataipora
# Processing Record 355  | hofn
# Processing Record 356  | olinda
# City not found, skipping.....
# Processing Record 357  | christchurch
# Processing Record 358  | kangaatsiaq
# Processing Record 359  | torrevieja
# Processing Record 360  | nioro
# Processing Record 361  | carmelo
# Processing Record 362  | tautira
# Processing Record 363  | camiri
# Processing Record 364  | antofagasta
# City not found, skipping.....
# Processing Record 365  | ust-omchug
# Processing Record 366  | rapid valley
# Processing Record 367  | kutum
# Processing Record 368  | meulaboh
# Processing Record 369  | gambela
# Processing Record 370  | litovko
# Processing Record 371  | petropavlovka
# Processing Record 372  | marivan
# Processing Record 373  | treinta y tres
# Processing Record 374  | san martino di lupari
# City not found, skipping.....
# Processing Record 375  | the valley
# Processing Record 376  | joao neiva
# Processing Record 377  | edgewater
# Processing Record 378  | pacific grove
# Processing Record 379  | san policarpo
# Processing Record 380  | namikupa
# Processing Record 381  | kota
# Processing Record 382  | sioux lookout
# Processing Record 383  | miraflores
# City not found, skipping.....
# City not found, skipping.....
# Processing Record 384  | mananjary
# Processing Record 385  | reconquista
# Processing Record 386  | qasigiannguit
# Processing Record 387  | petropavlovsk-kamchatskiy
# City not found, skipping.....
# Processing Record 388  | arman
# Processing Record 389  | omboue
# Processing Record 390  | nome
# Processing Record 391  | jackson
# Processing Record 392  | outlook
# Processing Record 393  | moron
# Processing Record 394  | knysna
# Processing Record 395  | kidal
# City not found, skipping.....
# City not found, skipping.....
# Processing Record 396  | denpasar
# Processing Record 397  | maldonado
# City not found, skipping.....
# Processing Record 398  | faya
# Processing Record 399  | roald
# Processing Record 400  | manokwari
# Processing Record 401  | kathmandu
# Processing Record 402  | angoche
# Processing Record 403  | el alto
# Processing Record 404  | atambua
# Processing Record 405  | la palma
# Processing Record 406  | ewa beach
# Processing Record 407  | ampanihy
# Processing Record 408  | kavaratti
# Processing Record 409  | boguchany
# Processing Record 410  | saint-joseph
# Processing Record 411  | bambous virieux
# Processing Record 412  | sambava
# City not found, skipping.....
# Processing Record 413  | palana
# Processing Record 414  | cervo
# Processing Record 415  | talaya
# Processing Record 416  | krutinka
# Processing Record 417  | colares
# Processing Record 418  | gazanjyk
# Processing Record 419  | chuy
# Processing Record 420  | dakar
# City not found, skipping.....
# Processing Record 421  | bodden town
# Processing Record 422  | xining
# Processing Record 423  | ust-nera
# Processing Record 424  | grand gaube
# Processing Record 425  | salta
# Processing Record 426  | cidreira
# Processing Record 427  | hokitika
# Processing Record 428  | vodnyy
# Processing Record 429  | luancheng
# Processing Record 430  | oistins
# Processing Record 431  | katakwi
# Processing Record 432  | farah
# Processing Record 433  | beberibe
# Processing Record 434  | mindelo
# Processing Record 435  | salto
# Processing Record 436  | yerbogachen
# Processing Record 437  | selikhino
# Processing Record 438  | sirjan
# City not found, skipping.....
# Processing Record 439  | port hedland
# Processing Record 440  | luena
# Processing Record 441  | klaksvik
# City not found, skipping.....
# Processing Record 442  | saint george
# Processing Record 443  | sola
# Processing Record 444  | dunda
# Processing Record 445  | rawson
# City not found, skipping.....
# Processing Record 446  | menongue
# Processing Record 447  | sangre grande
# Processing Record 448  | nicoya
# Processing Record 449  | buchanan
# Processing Record 450  | bang saphan
# Processing Record 451  | garissa
# City not found, skipping.....
# Processing Record 452  | itoman
# City not found, skipping.....
# Processing Record 453  | bagru
# Processing Record 454  | porto novo
# Processing Record 455  | berlevag
# Processing Record 456  | otradnoye
# Processing Record 457  | marzuq
# Processing Record 458  | molchanovo
# Processing Record 459  | tessalit
# Processing Record 460  | tezu
# Processing Record 461  | pontianak
# Processing Record 462  | lixourion
# Processing Record 463  | henties bay
# Processing Record 464  | jijiga
# Processing Record 465  | izvoru crisului
# Processing Record 466  | negombo
# Processing Record 467  | atbasar
# Processing Record 468  | danshui
# Processing Record 469  | sena madureira
# Processing Record 470  | prainha
# Processing Record 471  | tucurui
# Processing Record 472  | bonavista
# City not found, skipping.....
# Processing Record 473  | luwuk
# Processing Record 474  | malanville
# Processing Record 475  | bilibino
# Processing Record 476  | touros
# Processing Record 477  | tombouctou
# Processing Record 478  | damaturu
# Processing Record 479  | onega
# Processing Record 480  | akdepe
# Processing Record 481  | delmenhorst
# Processing Record 482  | camacha
# Processing Record 483  | batagay-alyta
# Processing Record 484  | valparaiso
# Processing Record 485  | adre
# Processing Record 486  | safranbolu
# Processing Record 487  | bubaque
# Processing Record 488  | yunyang
# City not found, skipping.....
# Processing Record 489  | urucui
# Processing Record 490  | pingliang
# Processing Record 491  | adeje
# Processing Record 492  | machico
# City not found, skipping.....
# Processing Record 493  | viransehir
# Processing Record 494  | diffa
# Processing Record 495  | khani
# Processing Record 496  | ipixuna
# Processing Record 497  | broken hill
# Processing Record 498  | lang son
# Processing Record 499  | dawei
# Processing Record 500  | sokoni
# Processing Record 501  | mao
# Processing Record 502  | manavgat
# Processing Record 503  | coquimbo
# Processing Record 504  | portland
# Processing Record 505  | kedougou
# City not found, skipping.....
# Processing Record 506  | price
# Processing Record 507  | demirci
# Processing Record 508  | pavlovskiy
# Processing Record 509  | cockburn town
# Processing Record 510  | barao de melgaco
# Processing Record 511  | trairi
# Processing Record 512  | woodward
# Processing Record 513  | santa maria
# Processing Record 514  | makakilo city
# City not found, skipping.....
# Processing Record 515  | tuatapere
# Processing Record 516  | kiruna
# Processing Record 517  | waipawa
# Processing Record 518  | trelew
# Processing Record 519  | xai-xai
# Processing Record 520  | deputatskiy
# Processing Record 521  | abha
# Processing Record 522  | houston
# Processing Record 523  | grand forks
# Processing Record 524  | umm kaddadah
# Processing Record 525  | rolleston
# City not found, skipping.....
# Processing Record 526  | moctezuma
# City not found, skipping.....
# Processing Record 527  | beloha
# Processing Record 528  | pyay
# Processing Record 529  | vuktyl
# Processing Record 530  | nelson bay
# Processing Record 531  | tyrma
# Processing Record 532  | riohacha
# Processing Record 533  | requena
# Processing Record 534  | araxa
# Processing Record 535  | polyarnyy
# Processing Record 536  | jalu
# Processing Record 537  | viedma
# Processing Record 538  | selizharovo
# Processing Record 539  | syracuse
# Processing Record 540  | kieta
# Processing Record 541  | calvinia
# City not found, skipping.....
# Processing Record 542  | mehamn
# Processing Record 543  | sisimiut
# City not found, skipping.....
# Processing Record 544  | lagos
# Processing Record 545  | sao joao da barra
# Processing Record 546  | kikwit
# Processing Record 547  | dukat
# Processing Record 548  | gerzat
# Processing Record 549  | emba
# Processing Record 550  | caxito
# Processing Record 551  | general roca
# Processing Record 552  | marsh harbour
# Processing Record 553  | port macquarie
# ----------------------------
# Data Retrival Complete
# ----------------------------

# %%
weather_dict={
    "City":city_name,
    "Cloudiness":cloudiness,
    "Country":country,
    "Date":date,
    "Humidity":humidity,
    "Lat":lat,
    "Lng":lng,
    "Max Temp":max_temp,
    "Wind Speed":wind_speed
}

# %%
#creating Data Frame
weatherDF=pd.DataFrame(weather_dict)
#Display Count

# %%
weatherDF.count()
# Out:
# City          552
# Cloudiness    552
# Country       552
# Date          552
# Humidity      552
# Lat           552
# Lng           552
# Max Temp      552
# Wind Speed    552
# dtype: int64

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#save data frame to CSV
weatherDF.to_csv('weather_data.csv')
#Display data from head
weatherDF.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Arraial do Cabo           0      BR  1554438554        90 -22.97  -42.02
# 1       Nikolskoye           0      RU  1554438336        64  59.70   30.79
# 2           Bethel           1      US  1554432960        47  60.79 -161.76
# 3           Avarua          68      CK  1554435000        74 -21.21 -159.78
# 4          Qaanaaq          48      GL  1554438590        80  77.48  -69.36
#
#    Max Temp  Wind Speed
# 0     78.53       19.26
# 1     37.00        2.24
# 2     37.40       18.34
# 3     78.80        3.36
# 4      0.86        5.73

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weatherDF["Lat"],weatherDF["Max Temp"],marker="o",edgecolors="black",alpha=0.75)
plt.grid(True)
plt.title("City Latitude Vs Max Temprature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.savefig("MaxTemp_v_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weatherDF["Lat"],weatherDF["Humidity"],marker="o",edgecolors="black",alpha=0.75)
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Humidity_vs_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weatherDF["Lat"],weatherDF["Cloudiness"],marker="o",edgecolors="black")
plt.grid(True)
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.title("Latitude vs Cloudiness")
plt.savefig("Latitude_vs_Cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weatherDF["Lat"],weatherDF["Wind Speed"],marker="o",edgecolors="black")
plt.grid(True)
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.title("Latitude vs Wind Speed")
plt.show()

# %%
print("Data analysis & charts reflect that the analysis summary holds true.")
# Out:
# Data analysis & charts reflect that the analysis summary holds true.
