# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+api_key

# %%
city_name=[]
cloudiness=[]
country=[]
date=[]
humidity=[]
max_temp=[]
lat=[]
lng=[]
wind_speed=[]
city_record=[]
#Print to logger
print("Begin Data Retrival")
print("----------------------------")
counter=1
for city in cities:
    try:
        
        response=requests.get(f"{base_url}&q={city}").json()
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record.append(response["name"])
        print(f"Processing Record {counter}  | {city}")
        counter=counter+1
    except:
        print("City not found, skipping.....")

print("----------------------------")        
print("Data Retrival Complete")
print("----------------------------")
# Out:
# Begin Data Retrival
# ----------------------------
# Processing Record 1  | hithadhoo
# Processing Record 2  | victoria
# Processing Record 3  | bethel
# Processing Record 4  | kaeo
# Processing Record 5  | college
# Processing Record 6  | rikitea
# Processing Record 7  | albany
# Processing Record 8  | rupert
# City not found, skipping.....
# Processing Record 9  | hobart
# Processing Record 10  | bredasdorp
# Processing Record 11  | bomi
# Processing Record 12  | cape town
# Processing Record 13  | hambantota
# Processing Record 14  | cabo san lucas
# Processing Record 15  | ushuaia
# Processing Record 16  | avarua
# Processing Record 17  | busselton
# Processing Record 18  | batagay
# Processing Record 19  | umm kaddadah
# Processing Record 20  | nome
# Processing Record 21  | leningradskiy
# City not found, skipping.....
# Processing Record 22  | coquimbo
# Processing Record 23  | narsaq
# Processing Record 24  | merauke
# Processing Record 25  | constitucion
# Processing Record 26  | tuktoyaktuk
# Processing Record 27  | canakkale
# Processing Record 28  | yellowknife
# Processing Record 29  | batsfjord
# Processing Record 30  | mataura
# Processing Record 31  | waitati
# Processing Record 32  | port alfred
# Processing Record 33  | haines junction
# Processing Record 34  | barrow
# Processing Record 35  | chuy
# Processing Record 36  | kapaa
# Processing Record 37  | vila franca do campo
# Processing Record 38  | svetlogorsk
# Processing Record 39  | luderitz
# Processing Record 40  | fria
# Processing Record 41  | georgetown
# Processing Record 42  | porto walter
# Processing Record 43  | carlos chagas
# Processing Record 44  | kodiak
# Processing Record 45  | progreso
# City not found, skipping.....
# Processing Record 46  | lebu
# City not found, skipping.....
# Processing Record 47  | shostka
# Processing Record 48  | saint george
# Processing Record 49  | serebryanyy bor
# Processing Record 50  | upernavik
# Processing Record 51  | windhoek
# Processing Record 52  | qaanaaq
# Processing Record 53  | coahuayana
# Processing Record 54  | dikson
# City not found, skipping.....
# Processing Record 55  | port hardy
# Processing Record 56  | ahipara
# Processing Record 57  | road town
# Processing Record 58  | castro
# Processing Record 59  | taoudenni
# Processing Record 60  | yaan
# Processing Record 61  | atuona
# City not found, skipping.....
# Processing Record 62  | thompson
# Processing Record 63  | bluff
# Processing Record 64  | belvedere marittimo
# Processing Record 65  | palembang
# Processing Record 66  | katsuura
# Processing Record 67  | nemuro
# Processing Record 68  | jamestown
# Processing Record 69  | leh
# Processing Record 70  | arraial do cabo
# Processing Record 71  | camacha
# Processing Record 72  | fortuna
# Processing Record 73  | baruun-urt
# City not found, skipping.....
# Processing Record 74  | saint anthony
# Processing Record 75  | iracoubo
# City not found, skipping.....
# Processing Record 76  | vaini
# City not found, skipping.....
# Processing Record 77  | shieli
# Processing Record 78  | gombe
# City not found, skipping.....
# Processing Record 79  | provideniya
# Processing Record 80  | hermanus
# Processing Record 81  | nikolskoye
# City not found, skipping.....
# Processing Record 82  | pevek
# Processing Record 83  | simbahan
# Processing Record 84  | lagoa
# Processing Record 85  | pisco
# Processing Record 86  | carnarvon
# City not found, skipping.....
# City not found, skipping.....
# Processing Record 87  | nanortalik
# Processing Record 88  | new norfolk
# Processing Record 89  | kaitangata
# Processing Record 90  | hilo
# Processing Record 91  | airai
# Processing Record 92  | tezu
# Processing Record 93  | khatanga
# Processing Record 94  | morros
# Processing Record 95  | bandarbeyla
# Processing Record 96  | sao filipe
# Processing Record 97  | kamenka
# Processing Record 98  | santa isabel do rio negro
# Processing Record 99  | saskylakh
# Processing Record 100  | ugoofaaru
# Processing Record 101  | galveston
# Processing Record 102  | ilulissat
# Processing Record 103  | hun
# City not found, skipping.....
# City not found, skipping.....
# Processing Record 104  | pochutla
# Processing Record 105  | misratah
# Processing Record 106  | the valley
# Processing Record 107  | nishihara
# Processing Record 108  | sept-iles
# Processing Record 109  | vredefort
# Processing Record 110  | sitka
# Processing Record 111  | puerto ayora
# Processing Record 112  | hamilton
# Processing Record 113  | east london
# Processing Record 114  | chicama
# Processing Record 115  | sinnamary
# Processing Record 116  | okhotsk
# Processing Record 117  | mindyak
# Processing Record 118  | boa vista
# Processing Record 119  | saint-philippe
# Processing Record 120  | poum
# City not found, skipping.....
# Processing Record 121  | bilma
# Processing Record 122  | matamoros
# Processing Record 123  | esperance
# Processing Record 124  | melfort
# Processing Record 125  | bolobo
# Processing Record 126  | omboue
# Processing Record 127  | vardo
# Processing Record 128  | zwedru
# Processing Record 129  | warrington
# Processing Record 130  | san luis
# Processing Record 131  | mount isa
# Processing Record 132  | geraldton
# Processing Record 133  | souillac
# Processing Record 134  | paamiut
# Processing Record 135  | port macquarie
# Processing Record 136  | vao
# Processing Record 137  | mackay
# Processing Record 138  | ancud
# Processing Record 139  | lompoc
# Processing Record 140  | viedma
# Processing Record 141  | tasiilaq
# Processing Record 142  | anjozorobe
# Processing Record 143  | westport
# Processing Record 144  | nguru
# Processing Record 145  | pangkalanbuun
# Processing Record 146  | cao bang
# Processing Record 147  | trapani
# Processing Record 148  | iguape
# Processing Record 149  | dingle
# Processing Record 150  | huarmey
# Processing Record 151  | pangnirtung
# Processing Record 152  | terney
# Processing Record 153  | namatanai
# Processing Record 154  | yumen
# City not found, skipping.....
# Processing Record 155  | honiara
# Processing Record 156  | hualmay
# Processing Record 157  | batangafo
# Processing Record 158  | exeter
# Processing Record 159  | wattegama
# Processing Record 160  | codrington
# Processing Record 161  | el cope
# Processing Record 162  | namibe
# Processing Record 163  | nizhniy odes
# City not found, skipping.....
# Processing Record 164  | culiacan
# City not found, skipping.....
# Processing Record 165  | poso
# Processing Record 166  | butaritari
# Processing Record 167  | freetown
# Processing Record 168  | wukari
# Processing Record 169  | coihaique
# Processing Record 170  | barahona
# City not found, skipping.....
# City not found, skipping.....
# Processing Record 171  | along
# Processing Record 172  | ambulu
# Processing Record 173  | pangody
# Processing Record 174  | bathsheba
# Processing Record 175  | berezovyy
# Processing Record 176  | kiunga
# Processing Record 177  | ostrovnoy
# Processing Record 178  | san patricio
# Processing Record 179  | macomer
# Processing Record 180  | mar del plata
# Processing Record 181  | urusha
# Processing Record 182  | karratha
# Processing Record 183  | santa fe
# Processing Record 184  | bambous virieux
# Processing Record 185  | krapina
# City not found, skipping.....
# Processing Record 186  | udachnyy
# Processing Record 187  | yulara
# Processing Record 188  | punta arenas
# Processing Record 189  | torbay
# Processing Record 190  | bol
# Processing Record 191  | laguna
# Processing Record 192  | kangaatsiaq
# Processing Record 193  | sandovo
# Processing Record 194  | skjervoy
# Processing Record 195  | mandvi
# City not found, skipping.....
# Processing Record 196  | comodoro rivadavia
# Processing Record 197  | hami
# Processing Record 198  | meulaboh
# Processing Record 199  | luwuk
# Processing Record 200  | acapulco
# Processing Record 201  | caravelas
# City not found, skipping.....
# Processing Record 202  | ambilobe
# Processing Record 203  | faanui
# Processing Record 204  | camudmud
# Processing Record 205  | praya
# Processing Record 206  | klaksvik
# Processing Record 207  | havre-saint-pierre
# City not found, skipping.....
# Processing Record 208  | puerto del rosario
# Processing Record 209  | jaciara
# Processing Record 210  | sao gabriel da cachoeira
# Processing Record 211  | kasongo-lunda
# Processing Record 212  | port elizabeth
# Processing Record 213  | norman wells
# Processing Record 214  | ampanihy
# Processing Record 215  | salalah
# Processing Record 216  | naze
# Processing Record 217  | fairbanks
# Processing Record 218  | ust-kuyga
# Processing Record 219  | tallahassee
# Processing Record 220  | kontagora
# Processing Record 221  | chokurdakh
# Processing Record 222  | kanigiri
# City not found, skipping.....
# City not found, skipping.....
# City not found, skipping.....
# City not found, skipping.....
# Processing Record 223  | asahi
# Processing Record 224  | ravar
# Processing Record 225  | san quintin
# Processing Record 226  | manggar
# Processing Record 227  | severo-kurilsk
# City not found, skipping.....
# Processing Record 228  | alice springs
# Processing Record 229  | copiapo
# Processing Record 230  | vung tau
# Processing Record 231  | pontianak
# Processing Record 232  | perpignan
# Processing Record 233  | egvekinot
# Processing Record 234  | vysokogornyy
# Processing Record 235  | beringovskiy
# Processing Record 236  | husavik
# Processing Record 237  | guaranda
# Processing Record 238  | okha
# Processing Record 239  | tilichiki
# Processing Record 240  | kruisfontein
# Processing Record 241  | kahului
# Processing Record 242  | ambon
# Processing Record 243  | alyangula
# Processing Record 244  | gainesville
# Processing Record 245  | nicoya
# Processing Record 246  | krasnopavlivka
# Processing Record 247  | necochea
# Processing Record 248  | verkhnevilyuysk
# Processing Record 249  | manoel urbano
# Processing Record 250  | port hedland
# Processing Record 251  | ha giang
# Processing Record 252  | anadyr
# Processing Record 253  | valparaiso
# Processing Record 254  | harboore
# Processing Record 255  | sibu
# Processing Record 256  | san miguel
# Processing Record 257  | aswan
# Processing Record 258  | escarcega
# Processing Record 259  | marabba
# Processing Record 260  | whitianga
# Processing Record 261  | jining
# Processing Record 262  | katastarion
# Processing Record 263  | feldkirchen
# Processing Record 264  | flagstaff
# Processing Record 265  | voronezh
# City not found, skipping.....
# Processing Record 266  | bonthe
# Processing Record 267  | mount gambier
# City not found, skipping.....
# Processing Record 268  | puerto colombia
# Processing Record 269  | havoysund
# Processing Record 270  | jiwani
# Processing Record 271  | chumikan
# Processing Record 272  | sabha
# Processing Record 273  | nouadhibou
# Processing Record 274  | batagay-alyta
# Processing Record 275  | broome
# Processing Record 276  | cidreira
# Processing Record 277  | muros
# Processing Record 278  | kayes
# Processing Record 279  | sao joao da barra
# Processing Record 280  | ribeira grande
# Processing Record 281  | pandan
# City not found, skipping.....
# Processing Record 282  | cherskiy
# Processing Record 283  | bonavista
# Processing Record 284  | strezhevoy
# Processing Record 285  | barranca
# Processing Record 286  | kindu
# Processing Record 287  | paradise
# Processing Record 288  | rocha
# Processing Record 289  | tiksi
# Processing Record 290  | ixtapa
# Processing Record 291  | hasaki
# Processing Record 292  | ossora
# Processing Record 293  | faya
# Processing Record 294  | umm lajj
# Processing Record 295  | richards bay
# Processing Record 296  | praia da vitoria
# Processing Record 297  | tripoli
# Processing Record 298  | phalodi
# Processing Record 299  | verkh-usugli
# Processing Record 300  | aksu
# Processing Record 301  | tual
# Processing Record 302  | beidao
# Processing Record 303  | clyde river
# Processing Record 304  | anloga
# Processing Record 305  | samfya
# Processing Record 306  | ilula
# Processing Record 307  | high level
# Processing Record 308  | saint-augustin
# Processing Record 309  | atasu
# Processing Record 310  | kununurra
# Processing Record 311  | grindavik
# Processing Record 312  | plainview
# Processing Record 313  | chateaubelair
# Processing Record 314  | mastung
# Processing Record 315  | zhigansk
# Processing Record 316  | oshikango
# Processing Record 317  | avera
# Processing Record 318  | wainwright
# City not found, skipping.....
# Processing Record 319  | talnakh
# Processing Record 320  | la rioja
# Processing Record 321  | tuatapere
# Processing Record 322  | rantauprapat
# Processing Record 323  | pallasovka
# Processing Record 324  | saldanha
# Processing Record 325  | sabang
# Processing Record 326  | port-gentil
# Processing Record 327  | mokrousovo
# Processing Record 328  | jacksonville
# Processing Record 329  | gat
# Processing Record 330  | salem
# Processing Record 331  | severnoye
# Processing Record 332  | longyearbyen
# Processing Record 333  | thinadhoo
# City not found, skipping.....
# Processing Record 334  | port blair
# Processing Record 335  | ahuimanu
# Processing Record 336  | fort nelson
# Processing Record 337  | iskateley
# Processing Record 338  | biak
# Processing Record 339  | sterling
# City not found, skipping.....
# Processing Record 340  | kyzyl
# Processing Record 341  | labuhan
# Processing Record 342  | kasane
# Processing Record 343  | maniwaki
# Processing Record 344  | marawi
# City not found, skipping.....
# Processing Record 345  | kralendijk
# Processing Record 346  | kishi
# Processing Record 347  | brigantine
# Processing Record 348  | tomatlan
# Processing Record 349  | missoula
# Processing Record 350  | lhokseumawe
# Processing Record 351  | port lincoln
# Processing Record 352  | nieuw amsterdam
# City not found, skipping.....
# Processing Record 353  | shingu
# City not found, skipping.....
# Processing Record 354  | kobryn
# Processing Record 355  | la asuncion
# Processing Record 356  | mabaruma
# Processing Record 357  | basco
# Processing Record 358  | celestun
# Processing Record 359  | presidente medici
# Processing Record 360  | los alamos
# Processing Record 361  | caldwell
# Processing Record 362  | touros
# Processing Record 363  | nyurba
# Processing Record 364  | zhanaozen
# Processing Record 365  | garissa
# Processing Record 366  | plettenberg bay
# Processing Record 367  | taltal
# Processing Record 368  | kholm
# Processing Record 369  | inta
# Processing Record 370  | hofn
# Processing Record 371  | vilhena
# Processing Record 372  | maymyo
# Processing Record 373  | srednekolymsk
# Processing Record 374  | hopkinsville
# Processing Record 375  | yar-sale
# Processing Record 376  | manta
# Processing Record 377  | san cristobal
# Processing Record 378  | pangai
# Processing Record 379  | nantucket
# City not found, skipping.....
# Processing Record 380  | nova olimpia
# Processing Record 381  | ostersund
# Processing Record 382  | nong bua
# Processing Record 383  | boguchany
# Processing Record 384  | pasni
# Processing Record 385  | belmonte
# Processing Record 386  | dudinka
# Processing Record 387  | makat
# Processing Record 388  | savannah bight
# Processing Record 389  | obidos
# Processing Record 390  | burns lake
# Processing Record 391  | boyolangu
# Processing Record 392  | altamira
# Processing Record 393  | coxim
# Processing Record 394  | malinovoye ozero
# Processing Record 395  | alofi
# Processing Record 396  | waingapu
# Processing Record 397  | mogadishu
# Processing Record 398  | olcea
# Processing Record 399  | beloha
# Processing Record 400  | lyuban
# Processing Record 401  | pervomayskoye
# Processing Record 402  | tura
# Processing Record 403  | brae
# City not found, skipping.....
# Processing Record 404  | dunedin
# Processing Record 405  | roma
# Processing Record 406  | orel-izumrud
# Processing Record 407  | mozarlandia
# Processing Record 408  | la ronge
# Processing Record 409  | margate
# Processing Record 410  | la palma
# Processing Record 411  | mikuni
# Processing Record 412  | vestmannaeyjar
# Processing Record 413  | jaicos
# City not found, skipping.....
# City not found, skipping.....
# Processing Record 414  | mineros
# Processing Record 415  | cururupu
# Processing Record 416  | calvia
# Processing Record 417  | bichura
# Processing Record 418  | warrnambool
# Processing Record 419  | concarneau
# Processing Record 420  | nacala
# Processing Record 421  | sioux lookout
# Processing Record 422  | storforshei
# Processing Record 423  | uncia
# Processing Record 424  | massaguet
# City not found, skipping.....
# Processing Record 425  | klyuchi
# Processing Record 426  | ocean city
# Processing Record 427  | antequera
# Processing Record 428  | meadow lake
# Processing Record 429  | itarema
# Processing Record 430  | waverly
# City not found, skipping.....
# Processing Record 431  | balkhash
# Processing Record 432  | saint-joseph
# Processing Record 433  | nikko
# Processing Record 434  | lahaina
# Processing Record 435  | havelock
# Processing Record 436  | bourail
# Processing Record 437  | quatre cocos
# Processing Record 438  | methoni
# Processing Record 439  | kalabo
# Processing Record 440  | baherden
# Processing Record 441  | verkhoyansk
# Processing Record 442  | chernyshevskiy
# Processing Record 443  | palenque
# Processing Record 444  | grand gaube
# Processing Record 445  | atar
# Processing Record 446  | weligama
# Processing Record 447  | coffs harbour
# Processing Record 448  | atbasar
# City not found, skipping.....
# Processing Record 449  | santa vitoria do palmar
# Processing Record 450  | chimbote
# Processing Record 451  | norilsk
# Processing Record 452  | manokwari
# Processing Record 453  | swidnik
# Processing Record 454  | erechim
# Processing Record 455  | bilibino
# Processing Record 456  | toropets
# Processing Record 457  | vega de alatorre
# Processing Record 458  | barmer
# Processing Record 459  | alcudia
# Processing Record 460  | diffa
# Processing Record 461  | baiao
# Processing Record 462  | mayo
# Processing Record 463  | karymskoye
# Processing Record 464  | saint-ambroise
# Processing Record 465  | aklavik
# City not found, skipping.....
# Processing Record 466  | ouegoa
# City not found, skipping.....
# Processing Record 467  | pacific grove
# Processing Record 468  | ahualulco
# Processing Record 469  | ponta do sol
# Processing Record 470  | midsalip
# Processing Record 471  | mahebourg
# Processing Record 472  | tutoia
# Processing Record 473  | guilin
# Processing Record 474  | huancabamba
# Processing Record 475  | mehamn
# Processing Record 476  | alindao
# Processing Record 477  | cap malheureux
# Processing Record 478  | champerico
# Processing Record 479  | ribeira brava
# Processing Record 480  | antofagasta
# Processing Record 481  | auki
# Processing Record 482  | iranshahr
# Processing Record 483  | englehart
# City not found, skipping.....
# Processing Record 484  | ocos
# Processing Record 485  | tambovka
# Processing Record 486  | glubokiy
# Processing Record 487  | hibbing
# Processing Record 488  | wake forest
# Processing Record 489  | tarauaca
# Processing Record 490  | ozernovskiy
# Processing Record 491  | sobolevo
# Processing Record 492  | roald
# Processing Record 493  | kikwit
# Processing Record 494  | djibo
# Processing Record 495  | newport
# Processing Record 496  | springbok
# City not found, skipping.....
# Processing Record 497  | bud
# Processing Record 498  | cedar city
# Processing Record 499  | basoko
# Processing Record 500  | oktyabrskiy
# Processing Record 501  | ayan
# Processing Record 502  | iqaluit
# Processing Record 503  | araouane
# Processing Record 504  | cristalina
# Processing Record 505  | roanoke rapids
# Processing Record 506  | kiruna
# Processing Record 507  | brown deer
# Processing Record 508  | sault sainte marie
# Processing Record 509  | pyay
# Processing Record 510  | zhongshu
# Processing Record 511  | aranos
# Processing Record 512  | wanlaweyn
# Processing Record 513  | sechura
# Processing Record 514  | emerald
# Processing Record 515  | turukhansk
# Processing Record 516  | cornwall
# Processing Record 517  | chandbali
# Processing Record 518  | sur
# Processing Record 519  | douentza
# Processing Record 520  | takoradi
# Processing Record 521  | wladyslawowo
# Processing Record 522  | isangel
# Processing Record 523  | atambua
# City not found, skipping.....
# Processing Record 524  | santa cruz cabralia
# Processing Record 525  | am timan
# Processing Record 526  | saint-doulchard
# Processing Record 527  | conceicao do mato dentro
# Processing Record 528  | paita
# City not found, skipping.....
# Processing Record 529  | yizheng
# Processing Record 530  | rosarito
# Processing Record 531  | berlin
# Processing Record 532  | troitsko-pechorsk
# Processing Record 533  | bapatla
# Processing Record 534  | vostok
# Processing Record 535  | peterhead
# Processing Record 536  | chara
# Processing Record 537  | yarim
# Processing Record 538  | topolobampo
# Processing Record 539  | malaia
# Processing Record 540  | kodinsk
# Processing Record 541  | berlevag
# Processing Record 542  | mecca
# Processing Record 543  | lata
# Processing Record 544  | chimoio
# Processing Record 545  | maumere
# Processing Record 546  | yakeshi
# Processing Record 547  | abu kamal
# Processing Record 548  | asyut
# Processing Record 549  | yabrud
# Processing Record 550  | tocopilla
# Processing Record 551  | kavieng
# Processing Record 552  | quimper
# City not found, skipping.....
# Processing Record 553  | paraiso
# Processing Record 554  | langsa
# Processing Record 555  | kichera
# Processing Record 556  | sao fidelis
# Processing Record 557  | wewak
# Processing Record 558  | poronaysk
# Processing Record 559  | pili
# ----------------------------
# Data Retrival Complete
# ----------------------------

# %%
weather_dict={
    "City":city_name,
    "Cloudiness":cloudiness,
    "Country":country,
    "Date":date,
    "Humidity":humidity,
    "Lat":lat,
    "Lng":lng,
    "Max Temp":max_temp,
    "Wind Speed":wind_speed
}

# %%
#creating Data Frame
weatherDF=pd.DataFrame(weather_dict)
#Display Count
weatherDF.count()
# Out:
# City          559
# Cloudiness    559
# Country       559
# Date          559
# Humidity      559
# Lat           559
# Lng           559
# Max Temp      559
# Wind Speed    559
# dtype: int64

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#save data frame to CSV
weatherDF.to_csv('weather_data.csv')
#Display data from head
weatherDF.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Hithadhoo           0      MV  1554579503       100  -0.60   73.08
# 1   Victoria          75      BN  1554577200        83   5.28  115.24
# 2     Bethel          75      US  1554577200        73  60.79 -161.76
# 3       Kaeo           0      NZ  1554579485        95 -35.10  173.78
# 4    College          75      US  1554579220        55  64.86 -147.80
#
#    Max Temp  Wind Speed
# 0     84.13        6.53
# 1     82.40        3.36
# 2     28.40       16.11
# 3     53.01        6.20
# 4     35.60        8.05

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weatherDF["Lat"],weatherDF["Max Temp"],marker="o",edgecolors="black",alpha=0.75)
plt.grid(True)
plt.title("City Latitude Vs Max Temprature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.savefig("MaxTemp_v_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weatherDF["Lat"],weatherDF["Humidity"],marker="o",edgecolors="black",alpha=0.75)
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Humidity_vs_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weatherDF["Lat"],weatherDF["Cloudiness"],marker="o",edgecolors="black")
plt.grid(True)
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.title("Latitude vs Cloudiness")
plt.savefig("Latitude_vs_Cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weatherDF["Lat"],weatherDF["Wind Speed"],marker="o",edgecolors="black")
plt.grid(True)
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.title("Latitude vs Wind Speed")
plt.savefig("Latitude_vs_WindSpeed.png")
plt.show()

# %%
print("Data analysis & charts reflect that the analysis summary holds true.")
# Out:
# Data analysis & charts reflect that the analysis summary holds true.
