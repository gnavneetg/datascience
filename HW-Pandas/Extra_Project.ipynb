# %%
# Dependencies
import pandas as pd

# %%
# load CSV
bootcamp=pd.read_csv("resources/2016-FCC-New-Coders-Survey-Data.csv",low_memory=False)

# %%
# Read with pandas
bootcamp.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber       ...       ResourceSoloLearn  \
# ...

# %%
# Inspect all columns
bootcamp.columns
# Out:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampFullJobAfter',
#        'BootcampLoanYesNo', 'BootcampMonthsAgo', 'BootcampName',
#        'BootcampPostSalary', 'BootcampRecommend', 'ChildrenNumber',
#        ...
#        'ResourceSoloLearn', 'ResourceStackOverflow', 'ResourceTreehouse',
#        'ResourceUdacity', 'ResourceUdemy', 'ResourceW3Schools',
#        'ResourceYouTube', 'SchoolDegree', 'SchoolMajor', 'StudentDebtOwe'],
#       dtype='object', length=113)

# %%
# Extract only columns 0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
bootcampselect=bootcamp.iloc[:,[0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
bootcampselect.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 0                NaN                 NaN                NaN             NaN
# 1                NaN                 NaN                NaN             NaN
# 2                NaN                 NaN                NaN             NaN
# 3                NaN                 NaN                NaN             NaN
# 4                NaN                 NaN                NaN             NaN
#
#                   CityPopulation  CodeEventBootcamp               CountryLive  \
# ...

# %%
# Change "0" to "No" and "1" to "Yes" in response columns
replacements={
    0.0:"No",
    1.0:"Yes"
}
bootcampselect.replace(replacements,inplace=True)
bootcampselect.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo  BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 0               NaN                 NaN               NaN            NaN
# 1               NaN                 NaN               NaN            NaN
# 2               NaN                 NaN               NaN            NaN
# 3               NaN                 NaN               NaN            NaN
# 4               NaN                 NaN               NaN            NaN
#
#                   CityPopulation CodeEventBootcamp               CountryLive  \
# 0  between 100,000 and 1 million               NaN  United States of America
# ...

# %%
# Calculate total number of respondents in survey
count_survey=len(bootcampselect.index)

# %%
# Extract rows corresponding only to people who attended a bootcamp
bools=[]
for attendee in bootcampselect['AttendedBootcamp']:
    if attendee == "Yes":
        bools.append(True)
    else:
        bools.append(False)
attendees=pd.Series(bools)
bootcampattendee=bootcampselect[attendees]
count_attendees=len(bootcampselect[attendees].index)
average_age=round(bootcampattendee['Age'].mean(),2)

# %%
# Calculate average age of attendees

# Calculate how many people attended a bootcamp
bootcamp=round(count_attendees/count_survey*100,2)



# Calculate how many attendees hold degrees
degree=bootcampattendee.groupby('SchoolDegree')
count_degree=degree['AttendedBootcamp'].count().sum()

# Count number of attendees who self-identify as male; female; or are of non-binary gender identification

gender_female=bootcampattendee[bootcampattendee.Gender=="female"]
gender_male=bootcampattendee[bootcampattendee.Gender=="male"]
gender=bootcampattendee["Gender"].count()
print(gender)
gender_female_count=gender_female['AttendedBootcamp'].count()
gender_male_count=gender_male['AttendedBootcamp'].count()
# Calculate percentage of respondents who attended a bootcamp
bootcamp=round(count_attendees/count_survey*100,2)
# Calculate percentage of respondents belonging to each gender
male=round(gender_male_count/gender*100,2)
female=round(gender_female_count/gender*100,2)
# Calculate percentage of attendees with a school degree
percent_degree=round(count_degree/count_attendees*100,2)
# Calculate average post-bootcamp salary

avg_postsal=bootcampattendee["BootcampPostSalary"]
average_post_bootcamp_salary=round(avg_postsal.mean())
# Out:
# 833

# %%
# Create a new table consolodating above calculations

pdf=pd.DataFrame({"Total Surveyed":count_survey,"Total Bootcamp attendees":count_attendees,"% attended bootcamp":bootcamp, 
           'Aver. Age':average_age,"Has a degree":percent_degree,
          "% Male":male,"% Female":female,"% Non Gender Specific":100-(male+female),"Average Post Bootcamp Salary":average_post_bootcamp_salary
                 },index=[0])

pdf
# Out:
#    Total Surveyed  Total Bootcamp attendees  % attended bootcamp  Aver. Age  \
# 0           15620                       953                  6.1      31.07
#
#    Has a degree  % Male  % Female  % Non Gender Specific  \
# 0          87.3   59.54     39.14                   1.32
#
#    Average Post Bootcamp Salary
# 0                         63741

# %%
# Improve formatting before outputting spreadsheet
average_post_bootcamp_salary= (f'$ {average_post_bootcamp_salary:,.2f}')
average_post_bootcamp_salary
# Out:
# '$ 63,741.00'

# %%
# Export to Excel
pdf.to_excel("BootcampOutputPart_output.xlsx")
